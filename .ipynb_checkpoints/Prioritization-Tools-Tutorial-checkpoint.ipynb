# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy as ap
from scipy.stats import binned_statistic_dd
from scipy.stats import linregress

# %% [markdown]
# # Atmospheric Prioritization
#
# The goal of this code is to find planets which are good candidates for atmospheric follow-up. We are particularly interested in planets which are from poorly-covered regions of parameter space (e.g., smaller than previously-known planets, or around different types of star, or with more/less irradiation). Because the code was developed for TESS planets, we impose a cutoff at 11.2 R_e. If you change that, beware of the breakdown of the empirical mass-radius relationship for larger planets; you will need to implement a statistical model, e.g. mr_forecaster by Chen & Kipping 2017.

# %%
from priority_tools import *

# %% [markdown]
# # Loading the Necessary Data
#
# The first thing to do is get all the data set up. You need to load in the toi+ list (data/toi/toi+-...), where ... is the date of the most recent data release. If you are curious about previous releases, some of them are also in that directory. You also need the TIC star info, which has V, J, and K magnitudes that are missing from TOI+.

# %%
#generate the key names for all the TOI+ columns we need
rp_key,ms_key,pp_key,Ts_key,ars_key,Jmag_key,\
    Vmag_key,rs_key,dec_key,Fp_key,mp_key,\
    mp_units,id_key = tess_colnames()

#load the TOI+ list
toiplus = pd.read_csv('data/toi/toi+-2020-01-15.csv',
                      delimiter=',',header=4)

#load the TIC star info
TIC_info = pd.read_csv('data/exofop/TIC_star_info_jan_15_all.csv',
                       delimiter=',',header=10)

#run the data cleaning function 
tess = clean_tess_data(toiplus, TIC_info)

#load the known planets (and Kepler PCs) table, and merge it
kps = pd.read_csv(r'data/known_planets_and_pcs.csv')
d = tess.append(kps[kps['K_amp'] > 1.5],sort=False) 
    #the K_amp cut wasn't made in the data itself, but is 
    #necessary to cut some of those not-real long-period
    #KOIs as well as known planets for which we can't get masses

# %% [markdown]
# # Binning
#
# With all the data loaded, we can run the binning function and generate the pandas dataframe object that we can use for the rest of the analysis.

# %%
#defining the bins: log-uniform in radius and Fp, 
#uniform in Teff. Right now, you need 6 bin edges
#for radius and Fp and 4 for Teff; we can change
#that by editing the "labels" in binning_function
rad_bins = 10**(np.linspace(0,1.05,6)) 
fpl_bins = 10**(np.linspace(-1,4,6))
tef_bins = np.array([2500,3900,5200,6500])
bins = [rad_bins, fpl_bins, tef_bins]

b = binning_function(d, bins) #b stands for "binned", 
                            #to make use easier

# %% [markdown]
# # Playing With The Data
#
# Now, we can start looking at the data! Two very simple things we might want to do are look at a single TOI, and look at it in the context of its bin. If you've used pandas before, messing around with these data will be straightforward; if not, here are some useful tricks. To load a single object, use: b[b[id_key] == x], where x is the ID number including .01 or .02 (or .03, or whichever planet you want if it's a highly multiple system)

# %%
#make sure we can see the columns in the middle of the output
pd.options.display.max_columns = 100 

#call the request
b[b[id_key] == 1135.01]

#the output tells us the radius, insolation, and Teff bins, as
#well as all the data from the TOI plus list and values that
#we've calculated
# Out:
#                                  Source Pipeline          TIC Full TOI ID  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                      spoc  154872375.0     1135.01
#
#                                   TIC Right Ascension  TIC Declination  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                     193.395514        85.129473
#
#                                   TMag Value  TMag Uncertainty  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                 9.029             0.006
#
#                                   Orbital Epoch Value  Orbital Epoch Error  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                    1684.151629              0.00066
#
#                                   Orbital Period Value  Orbital Period Error  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                         8.02802               0.00035
#
#                                   Transit Duration Value  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                          4.480524
#
#                                   Transit Duration Error  Transit Depth Value  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                             0.087          5816.770203
#
#                                   Transit Depth Error Sectors Public Comment  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                       0.330706      14            NaN
#
#                                   Surface Gravity Value  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                             4.38
#
#                                   Surface Gravity Uncertainty  Signal ID  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                                   0.08        1.0
#
#                                   Star Radius Value  Star Radius Error  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                      1.15415               0.03
#
#                                   Planet Radius Value  Planet Radius Error  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                       9.001699              0.23487
#
#                                   Planet Equilibrium Temperature (K) Value  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                                         1011.007289
#
#                                   Effective Temperature Value  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                                 5962.7
#
#                                   Effective Temperature Uncertainty  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                                         68.6
#
#                                   Effective Stellar Flux Value  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                              246.909698
#
#                                   Signal-to-noise Centroid Offset  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3                   75.85142             NaN
#
#                                                    Alerted  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3            2019-08-27 16:09:24+0000
#
#                                                     Edited  Stellar Mass  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3            2019-12-17 15:43:39+0000      1.164534
#
#                                   pl_masses        Ars      K_amp  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3            60.187467  15.384734  17.396112
#
#                                        Target         RA        Dec  V mag  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3            154872375.0  193.39637  85.129495   9.54
#
#                                   J mag  H mag         TSM  Unnamed: 0  \
# radius_bin insol_bin st_Teff_bin
# 5          4         3            8.458  8.265  228.782967         NaN
#
#                                  radius_bin insol_bin st_Teff_bin  priority
# radius_bin insol_bin st_Teff_bin
# 5          4         3                    5         4           3       1.0

# %%
#you can also ask for a few specific columns if you want 
#a much less messy output

b[b[id_key] == 736.01][[rp_key,Ts_key,Fp_key,'TSM','V mag','priority']]
# Out:
#                                   Planet Radius Value  \
# radius_bin insol_bin st_Teff_bin
# 2          2         1                       2.019085
#
#                                   Effective Temperature Value  \
# radius_bin insol_bin st_Teff_bin
# 2          2         1                                 2940.0
#
#                                   Effective Stellar Flux Value         TSM  \
# radius_bin insol_bin st_Teff_bin
# 2          2         1                                1.958181  142.723769
#
#                                   V mag  priority
# radius_bin insol_bin st_Teff_bin
# 2          2         1            16.91       3.0

# %% [markdown]
# To look at an entire bin, use b.loc[x,y,z], where x, y, and z are the radius, insolation, and Teff bin, respetively. Note that these are 1-indexed, not 0-indexed (sorry). If it's priority values alone you're interested in, scroll all the way to the right.

# %%
#look into this bin, and select only the top 5 (by TSM)
b.loc[3,4,3].head(5)
# Out:
#                                  Source Pipeline          TIC  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                       NaN          NaN
#                      3                      spoc  142276270.0
#                      3                      spoc  119700084.0
#                      3                       NaN          NaN
#                      3                      spoc  124573851.0
#
#                                         Full TOI ID  TIC Right Ascension  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3            EPIC 212178066.01                  NaN
#                      3                      1136.02           192.184889
#                      3                      1413.01           333.252968
#                      3                    TOI 125 b                  NaN
#                      3                       669.01           158.900634
#
#                                   TIC Declination  TMag Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                  23.685905         NaN
#                      3                  64.855319      8.9360
#                      3                  37.627739     10.1188
#                      3                 -66.675819         NaN
#                      3                  -5.181666     10.1370
#
#                                   TMag Uncertainty  Orbital Epoch Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                         NaN                  NaN
#                      3                       0.006          1688.716985
#                      3                       0.006          1741.089886
#                      3                         NaN                  NaN
#                      3                       0.018          1546.136799
#
#                                   Orbital Epoch Error  Orbital Period Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                            NaN             15.613426
#                      3                       0.002097              6.256742
#                      3                       0.001290              6.116688
#                      3                            NaN              4.653820
#                      3                       0.005545              3.948678
#
#                                   Orbital Period Error  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                             NaN
#                      3                        0.001105
#                      3                        0.000728
#                      3                             NaN
#                      3                        0.001811
#
#                                   Transit Duration Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                               NaN
#                      3                          3.472081
#                      3                          0.532622
#                      3                               NaN
#                      3                          3.420507
#
#                                   Transit Duration Error  Transit Depth Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                               NaN                  NaN
#                      3                          0.330290           915.202251
#                      3                          0.598871          1631.660734
#                      3                               NaN                  NaN
#                      3                          0.343622           754.018523
#
#                                   Transit Depth Error Sectors  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                            NaN     NaN
#                      3                       74.03411      14
#                      3                      240.42992      16
#                      3                            NaN     NaN
#                      3                       68.20220       9
#
#                                                               Public Comment  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                                   NaN
#                      3                                                 multi
#                      3            Check nearby stars; Potential L1 candidate
#                      3                                                   NaN
#                      3                                                   NaN
#
#                                   Surface Gravity Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                              NaN
#                      3                          4.47000
#                      3                          4.51461
#                      3                              NaN
#                      3                          4.13000
#
#                                   Surface Gravity Uncertainty  Signal ID  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                    NaN        NaN
#                      3                               0.080000        2.0
#                      3                               0.083056        1.0
#                      3                                    NaN        NaN
#                      3                               0.120000        1.0
#
#                                   Star Radius Value  Star Radius Error  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                     1.440000                NaN
#                      3                     0.977727           0.048352
#                      3                     0.890109           0.050472
#                      3                     0.850000                NaN
#                      3                     1.152840           0.170302
#
#                                   Planet Radius Value  Planet Radius Error  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                       3.000000                  NaN
#                      3                       3.002270             0.883460
#                      3                       3.718569             8.670165
#                      3                       2.755000                  NaN
#                      3                       3.842242             0.628328
#
#                                   Planet Equilibrium Temperature (K) Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                                 NaN
#                      3                                          971.045159
#                      3                                          891.198032
#                      3                                                 NaN
#                      3                                         1283.435066
#
#                                   Effective Temperature Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                 6460.0
#                      3                                 5729.0
#                      3                                 5427.0
#                      3                                 5282.0
#                      3                                 5581.9
#
#                                   Effective Temperature Uncertainty  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                          NaN
#                      3                                      131.100
#                      3                                      141.322
#                      3                                          NaN
#                      3                                       76.000
#
#                                   Effective Stellar Flux Value  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                              175.034453
#                      3                              210.125477
#                      3                              149.079483
#                      3                              185.769244
#                      3                              641.234094
#
#                                   Signal-to-noise Centroid Offset  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                        NaN             NaN
#                      3                  12.109399             NaN
#                      3                   7.954413             NaN
#                      3                        NaN             NaN
#                      3                   9.629088             NaN
#
#                                                    Alerted  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                 NaN
#                      3            2019-10-17 00:30:12+0000
#                      3            2019-11-06 20:55:18+0000
#                      3                                 NaN
#                      3            2019-05-06 19:17:04+0000
#
#                                                     Edited  Stellar Mass  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                                 NaN      1.375159
#                      3            2019-12-17 15:43:43+0000      1.028166
#                      3            2019-12-17 15:43:43+0000      0.944331
#                      3                                 NaN      0.870000
#                      3            2019-12-17 15:43:39+0000      0.653380
#
#                                   pl_masses        Ars     K_amp       Target  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3             9.295239  20.307186  1.926533          NaN
#                      3             9.307199  14.754735  3.176226  142276270.0
#                      3            13.390395  15.518090  4.872916  119700084.0
#                      3             8.041900  13.178209  3.385788          NaN
#                      3            14.156258   7.915589  7.619698  124573851.0
#
#                                           RA        Dec   V mag  J mag  H mag  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3                   NaN        NaN   6.884  5.836    NaN
#                      3            192.184898  64.855276   9.534  8.363  8.088
#                      3            333.253171  37.627574  10.849  9.415  9.059
#                      3                   NaN        NaN  10.892  9.466    NaN
#                      3            158.900701  -5.181374  10.606  9.557  9.215
#
#                                          TSM  Unnamed: 0 radius_bin insol_bin  \
# radius_bin insol_bin st_Teff_bin
# 3          4         3            123.674687         0.0          3         4
#                      3             85.894169         NaN          3         4
#                      3             71.083909         NaN          3         4
#                      3             60.608491       136.0          3         4
#                      3             59.647313         NaN          3         4
#
#                                  st_Teff_bin  priority
# radius_bin insol_bin st_Teff_bin
# 3          4         3                     3       1.0
#                      3                     3       2.0
#                      3                     3       3.0
#                      3                     3       0.0
#                      3                     3       0.0

# %% [markdown]
# Let's try the visualization tool, which displays all the objects in a given radius bin. Dots scale linearly with planet radius. Labels indicate the object: floats are TOIs (i.e. "421.01" is TOI 421.01), anything starting with "K0" or "EPIC" is an unconfirmed KOI or K2 object, respectively, and everything else is a confirmed planet (including some previously-confirmed TOIs - for example TOI 270c falls into this category). Note that long-period KOIs (i.e., those in the top left - with relatively hot stars but earth-like insolation) are generally considered unreliable and should not automatically be assumed to actually exist or be good potential atmospheric targets.

# %%
#bin_plotter inputs are the binned data, the bin edges
#(as defined above), and the radius bin of interest
for i in np.arange(1,6):
    bin_plotter(b,bins,i)

# %%
#all priorities
all_priorities = b[b['priority']!=0].reset_index(drop=True)[id_key].values
high_p_tois = []
for obj in all_priorities:
    if type(obj) == float:
        high_p_tois.append(obj)
high_p_tois.sort()
high_p_tois
# Out:
# [239.01,
#  256.02,
#  278.01,
#  421.01,
#  455.01,
#  460.01,
#  469.01,
#  482.01,
#  507.01,
#  509.01,
#  519.01,
#  526.01,
#  529.01,
#  532.01,
#  538.01,
#  544.01,
#  560.01,
#  561.02,
#  564.01,
#  634.01,
#  635.01,
#  638.01,
#  654.01,
#  656.01,
#  680.01,
#  732.01,
#  736.01,
#  736.02,
#  737.01,
#  1135.01,
#  1136.02,
#  1144.01,
#  1173.01,
#  1179.01,
#  1201.01,
#  1238.02,
#  1242.01,
#  1243.01,
#  1254.01,
#  1256.01,
#  1260.01,
#  1273.01,
#  1276.01,
#  1278.01,
#  1283.01,
#  1285.01,
#  1288.01,
#  1289.01,
#  1339.01,
#  1410.01,
#  1412.01,
#  1413.01,
#  1416.01,
#  1419.01,
#  1423.01,
#  1430.01,
#  1436.01,
#  1442.01,
#  1448.01,
#  1449.01,
#  1459.01,
#  1470.01,
#  1471.01,
#  1473.01,
#  1474.01,
#  1598.01,
#  1632.01,
#  1634.01,
#  1638.01,
#  1639.01,
#  1640.01]
